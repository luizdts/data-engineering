# %% [markdown]
# # Importando as bibliotecas.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

# %matplotlib inline

# %% [markdown]
# ## Etapas do projeto
# - Coleta de dados
# - Análise de dados
# - Criação de modelos
# - Validação de modelos
# - Apresentação dos resultados

# %% [markdown]
# #### Parametros

# %%
dataset = "./data/ecomerce.csv"
model = "./model/"
test_size_ = 0.3
n_estimators = 100
max_depth = 10

# %%
# Parameters
test_size_ = 0.25
dataset = "./data/ecomerce.csv"
model = "./model/"
n_estimators = 1000
max_depth = 5

# %% [markdown]
# #### Leitura dos dados

# %%
clientes = pd.read_csv(dataset)

# %%
clientes.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# 3            34.305557    13.717514        36.721283              3.120179
# 4            33.330673    12.795189        37.536653              4.446308
#
#    Yearly Amount Spent
# 0           587.951054
# 1           392.204933
# 2           487.547505
# 3           581.852344
# 4           599.406092

# %%
clientes.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %% [markdown]
# - Qual a relação do cara que passa mais tempo no site em relação ao valor gasto anual?

# %%
sns.jointplot(x='Time on Website', y='Yearly Amount Spent', data=clientes)

# %% [markdown]
# - Qual a relação do cara que passa mais tempo no APP em relação ao valor gasto anual?

# %%
sns.jointplot(x='Time on App', y='Yearly Amount Spent', data=clientes)

# %% [markdown]
# - As pessoas que usam o aplicativo elas são clientes a mais tempo ou não?

# %%
sns.jointplot(x='Time on App', y='Length of Membership', data=clientes, kind='hex')

# %% [markdown]
# - Quais variáveis conseguimos explicar ou que tem maior impacto no quanto uma pessoa gasta no ano?

# %%
sns.pairplot(clientes)

# %% [markdown]
# - Como ficaria um modelo linear usando o Tempo de App em relação ao valor gasto?

# %%
sns.lmplot(x='Time on App', y='Yearly Amount Spent', data=clientes)

# %% [markdown]
# - Como ficaria um modelo linear usando o Tempo de Membro em relação ao valor gasto?

# %%
sns.lmplot(x='Length of Membership', y='Yearly Amount Spent', data=clientes)

# %% [markdown]
# ## 3. Criação de um Modelo com todas as variáveis

# %% [markdown]
# - Separa quem meu X e meu y

# %%
clientes.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# 3            34.305557    13.717514        36.721283              3.120179
# 4            33.330673    12.795189        37.536653              4.446308
#
#    Yearly Amount Spent
# 0           587.951054
# 1           392.204933
# 2           487.547505
# 3           581.852344
# 4           599.406092

# %%
y = clientes['Yearly Amount Spent']

# %%
X = clientes[['Avg. Session Length', 'Time on App','Time on Website', 'Length of Membership']]

# %% [markdown]
# - Dividir meu conjunto em treino e teste usando sckit learning

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train,y_test = train_test_split(X, y, test_size=test_size_,random_state=42)

# %%
y_train.shape
# Out:
# (375,)

# %%
y_test.shape
# Out:
# (125,)

# %% [markdown]
# - Criar um modelo de regressão linear usando sklearn

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(
            n_estimators = n_estimators,
            max_depth = max_depth,
)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=5, n_estimators=1000)

# %% [markdown]
# - Para validar o modelo no conjunto de teste, você precisa utilizar o método predict()

# %%
ỹ = rf.predict(X_test)

# %%
ỹ
# Out:
# array([429.64194414, 542.50415936, 491.63134939, 499.35344708,
#        436.88327308, 551.84181901, 510.90617812, 506.81270412,
#        414.43808074, 471.81783055, 447.16902673, 413.40432512,
#        437.56282085, 539.64471196, 424.46283771, 424.09508574,
#        568.1272058 , 478.16168273, 454.34085563, 480.48205595,
#        456.48391017, 504.19015313, 497.92766952, 609.72267156,
#        430.98218814, 509.37522233, 535.11535024, 550.81042675,
#        408.34457567, 365.54776047, 546.05443593, 483.41591298,
#        497.94106184, 314.05671786, 519.70152423, 475.46954012,
#        527.77760953, 437.97670369, 454.82340681, 476.64683087,
#        481.64433103, 421.04310106, 502.60485938, 500.83579538,
#        483.95435118, 538.83710666, 575.62066   , 518.6928499 ,
#        333.04877156, 445.14758419, 437.65149139, 485.66012145,
#        577.13594812, 590.47343052, 569.48240095, 485.4125409 ,
#        399.94785793, 423.7292313 , 553.31500109, 514.60118479,
#        504.11008127, 388.97219774, 494.14687985, 480.01726802,
#        471.47939657, 549.46025804, 418.71156848, 575.16902572,
#        448.90275944, 497.79842072, 525.84236885, 558.2712862 ,
#        616.08299648, 509.47720334, 415.30651518, 485.79421391,
#        478.6207776 , 447.99185638, 450.30267181, 503.7630077 ,
#        540.66113069, 601.22871656, 511.60004721, 635.00321403,
#        529.95268841, 452.36755431, 520.94155403, 546.70591629,
#        374.27650722, 505.21780924, 535.7104267 , 487.72716208,
#        418.93576762, 569.70834514, 464.63415149, 558.66257626,
#        478.23105389, 456.58921989, 430.22419922, 491.03531683,
#        523.62314605, 397.31882408, 575.44942504, 512.34706622,
#        398.31830115, 509.90513889, 499.81117929, 437.3788298 ,
#        533.14640661, 433.43881673, 418.72209658, 472.27792688,
#        457.96106056, 448.66277883, 654.20917866, 551.85363379,
#        607.04028137, 421.51616484, 545.08507827, 574.90807088,
#        519.78738876, 527.67434355, 387.04994478, 666.97166316,
#        515.84913346])

# %% [markdown]
# ** Crie um diagrama de dispersão (scatterplot) dos valores reais de teste em relação aos valores preditos. **

# %%
plt.scatter(y_test, ỹ)
plt.xlabel('y real')
plt.ylabel('ỹ predito')
# Out:
# Text(0, 0.5, 'ỹ predito')

# %% [markdown]
# #### Imprime os parametros do modelo.

# %%
print(rf.get_params())
# Out:
# {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 5, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 1000, 'n_jobs': None, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}

# %% [markdown]
# ## 4. Avaliando o Modelo

# %%
sns.displot(clientes, x="Yearly Amount Spent")
plt.tight_layout()

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, ỹ))
print('MSE:', metrics.mean_squared_error(y_test, ỹ))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, ỹ)))
print('R2:', metrics.r2_score(y_test,ỹ))
# Out:
# MAE: 17.28292106198573
# MSE: 490.6458671654865
# RMSE: 22.150527469238437
# R2: 0.9102229831831804

# %%
metricas = pd.DataFrame(data=None,columns=["MAE","MSE","RMSE","R2"])

# %%
metricas['MAE'] = [metrics.mean_absolute_error(y_test,ỹ)]
metricas['MSE'] = [metrics.mean_squared_error(y_test,ỹ)]
metricas['RMSE'] = [np.sqrt(metrics.mean_squared_error(y_test, ỹ))]
metricas['R2'] = [metrics.r2_score(y_test,ỹ)]

# %%
metricas.head()
# Out:
#          MAE         MSE       RMSE        R2
# 0  17.282921  490.645867  22.150527  0.910223

# %% [markdown]
# ## Exportando o modelo.

# %%
joblib.dump(rf,model+"model.joblib")
# Out:
# ['./model/model.joblib']

# %% [markdown]
# # Rodando o papermill
#
# papermill regression-project.ipynb output.ipynb -p test-size 0.25 -p dataset "./data/ecomerce.csv" -p model "./model/" -p n_estimators 1000 -p max_depth 5 --stdout-file test.txt --stderr-file err.txt
