# %%
# !pip install boto3 >log

# %%
import boto3
import json
import time
from random import uniform
from datetime import datetime

client = boto3.client('kinesis', aws_access_key_id='AKIA3FLD47354AP7UICM', aws_secret_access_key='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',
                      region_name='us-east-1')

id = 0

while True:
    dados = uniform(70,80)
    id += 1
    registro = {'idtemp': str(id), 'data' : str(dados), 'type': 'hydraulic_pressure', 'timestamp' : str(datetime.now()) }
    client.put_record(StreamName='windfarm', Data=json.dumps(registro), PartitionKey='02')
    time.sleep(10)
