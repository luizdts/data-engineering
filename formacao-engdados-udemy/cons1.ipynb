# %%
# !pip install boto3 >log

# %%
import boto3
import json

cliente = boto3.client('kinesis', aws_access_key_id = 'AKIA3FLD47354AP7UICM',
                       aws_secret_access_key= '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',
                       region_name='us-east-2')

shard = cliente.get_shard_iterator(StreamName='stream1',
                                   ShardId='shardId-000000000002',
                                   ShardIteratorType='LATEST'
                                   )["ShardIterator"]

while shard is not None:
    result = cliente.get_records(ShardIterator=shard)
    registers = result['Records']
    shard = result["NextShardIterator"]
    for register in registers:
        print(register["SequenceNumber"])
        print(register["ApproximateArrivalTimestamp"])
        print(register["PartitionKey"])
        print(register["Data"])
