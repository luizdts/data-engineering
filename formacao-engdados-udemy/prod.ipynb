# %%
# !pip install boto3 >log

# %%
import boto3
import json

cliente = boto3.client('kinesis', aws_access_key_id = 'AKIA3FLD47354AP7UICM',
                       aws_secret_access_key= '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',
                       region_name='us-east-2')

registro = {'idvendedor': '999', 'nome': 'Nelson'}

response = cliente.put_record(StreamName = 'stream1',
                              Data = json.dumps(registro),
                              PartitionKey='02'
                              )
print(response)
