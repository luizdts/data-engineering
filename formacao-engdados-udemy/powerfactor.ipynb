# %%
# !pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.34.36-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 3.7 MB/s eta 0:00:00
# Collecting botocore<1.35.0,>=1.34.36 (from boto3)
#   Downloading botocore-1.34.36-py3-none-any.whl (11.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 27.9 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3)
#   Downloading s3transfer-0.10.0-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.35.0,>=1.34.36->boto3) (2.8.2)
# Requirement already satisfied: urllib3<2.1,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<1.35.0,>=1.34.36->boto3) (2.0.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.0,>=1.34.36->boto3) (1.16.0)
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.34.36 botocore-1.34.36 jmespath-1.0.1 s3transfer-0.10.0

# %%
import boto3
import json
import time
from random import uniform
from datetime import datetime

client = boto3.client('kinesis', aws_access_key_id='AKIA3FLD47354AP7UICM', aws_secret_access_key='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',
                      region_name='us-east-1')

id = 0

while True:
    dados = uniform(0.7, 1)
    id += 1
    registro = {'idtemp': str(id), 'data' : str(dados), 'type': 'powerfactor', 'timestamp' : str(datetime.now()) }
    client.put_record(StreamName='windfarm', Data=json.dumps(registro), PartitionKey='02')
    time.sleep(10)
